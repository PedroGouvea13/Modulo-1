# %%
#algoritimo Para Caucular Resto da divisao

# %%
num1 = 0
num2 = 0
resto = 0

# %%
#recebendo dois numeros
num1 = int(input("Digite o primeiro numero. "))
num2 = int(input("Digite o segundo numero. "))
# Out:
# Digite o primeiro numero. 5
# Digite o segundo numero. 3

# %%
#calculando o resto da divisao
resto = num1 / num2

# %%
#Imprimindo o Resto
print (f'O resto da divisao e. {resto}')
# Out:
# O resto da divisao e. 1.6666666666666667
