# %% [markdown]
# <a href="https://colab.research.google.com/github/PedroGouvea13/Modulo-1/blob/main/1_4_Listas_de_valores.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# lista
  [1,2,3,4,5]

# %%
#Tupla
 (1,2,3,4,5)

# %%
#dicionario
  {"num1": 1, "num2": 2, "num3": 3}

# %%
lista = [5, "Rodrigo" , 8.9]

# %%
type(lista)
# Out:
# list

# %% [markdown]
# Lista

# %%
lista.append('Agusto') #Adicionar um elemto na lista

# %%
print(lista)
print(lista[1])
# Out:
# [5, 'Rodrigo', 8.9, 'Agusto']
# Rodrigo

# %% [markdown]
# Tupla

# %%
tupla = (5, "Rodrigo" , 8.9)

# %%
type (tupla)
# Out:
# tuple

# %%
tupla.append('Agusto')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_6433/774686083.py in <cell line: 0>()
# ----> 1 tupla.append('Agusto')
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
print(tupla)
print(tupla[1])
# Out:
# (5, 'Rodrigo', 8.9)
# Rodrigo

# %% [markdown]
# Dicionario

# %%
dicionario = {'nome':'Rodrigo','Cidade': 'Sao Jose dos Campos'}

# %%
type(dicionario)
# Out:
# dict

# %%
print(dicionario)
# Out:
# {'nume': 'Rodrigo', 'Cidade': 'Sao Jose dos Campos'}

# %%
print(dicionario['nome'])
# Out:
# Rodrigo

# %%
print(dicionario['Cidade'])
# Out:
# Sao Jose dos Campos

# %%
dicionario['ultimo_nome'] = 'Reboucas'
print(dicionario)
# Out:
# {'nome': 'Rodrigo', 'Cidade': 'Sao Jose dos Campos', 'ultimo_nome': 'Reboucas'}
